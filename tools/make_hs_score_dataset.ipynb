# %%
import pandas as pd

# df = pd.read_csv("/home/pgajo/working/data/datasets/English/Incels.is/IFC-22-EN_updated_hs_silver_labels_backup.csv")
df = pd.read_csv("/home/pgajo/working/data/datasets/Italian/Il_forum_dei_brutti/IFC-22-IT_updated_hs_silver_labels.csv")
df
# Out:
#         row_id  post_thread_num                    user  \
# 0            0                1            unbruttoblog
# 1            1                2               brutto 38
# 2            2                3                AnonY.0.
# 3            3                4               brutto 38
# 4            4                5                Pegasus1
# ...        ...              ...                     ...
# 638138   87704                3  Agato Christie Mazinga
# 638139   87705                1            DX2-Expresso
# 638140   87706                2              Ap0calipso
# 638141   87707                3                   Ogrod
# 638142   87708                4            Funestovento
#
#                                                      text  \
# 0       Ciao a tutti. rieccoci nuovamente on-line, in ...
# 1       Non me ne frega niente del ben ritrovato,io ti...
# 2                             HAHAHAHAHHHHAH sto morendo.
# ...

# %%
df['hs_predictions'].value_counts(normalize=1)
# Assuming your DataFrame is named 'df'
df['hs_score'] = None

# Group the dataframe by 'thread_id'
grouped = df.groupby('thread_id')

# Define a function to calculate the hs_score for each group
def calculate_hs_score(group):
    hs_sum = group['hs_predictions'][1:].sum()
    post_count = group.shape[0]
    hs_ratio = hs_sum / post_count
    group.iloc[0, df.columns.get_loc('hs_score')] = hs_ratio
    return group

# Apply the function to each group
df = grouped.apply(calculate_hs_score)

# Filter the dataframe to only keep the rows with the first post of each thread
first_posts = df[df['hs_score'].notnull()]
first_posts
# Out:
# /tmp/ipykernel_20124/1491342169.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df = grouped.apply(calculate_hs_score)
#         row_id  post_thread_num                    user  \
# 0            0                1            unbruttoblog
# 5            5                1                brutto38
# 168        168                1            unbruttoblog
# 1169      1169                1                brutto38
# 1208      1208                1                roberto*
# ...        ...              ...                     ...
# 638077   87643                1                   Mind.
# ...

# %%
# first_posts.to_csv("/home/pgajo/working/data/datasets/English/Incels.is/IFC-22-EN_updated_hs_scores_223k_exclOP.csv", index=False)
first_posts.to_csv("/home/pgajo/working/data/datasets/Italian/Il_forum_dei_brutti/IFC-22-IT_updated.csv_hs_scores_30k_exclOP.csv", index=False)

# %%
first_posts
# Out:
#           row_id post_thread_num            user  \
# 0              0               1      ItWontBeMe
# 6              6               1       iiiTeMpeR
# 14            14               1      ItWontBeMe
# 21            21               1          Morf12
# 31            31               1         Minjaze
# ...          ...             ...             ...
# 4756787  4756787               1          Zer0/∞
# 4756813  4756813               1  mistersinister
# 4756824  4756824               1         AsiaCel
# 4756862  4756862               1  mistersinister
# 4756869  4756869               1   Despicablecel
#
#                                                       text quote_text  \
# 0        Yeah, it's getting to that point now. Last yea...        NaN
# 6        Here' the post: https://www.reddit.com/r/ugly/...        NaN
# 14       { "lightbox_close": "Close", "lightbox_next": ...        NaN
# 21       And I'm not even sure if it exists but if it d...        NaN
# ...
